# %% [markdown]
# # <font color='brown'>__Water Quality Analysis__</font>

# %% [markdown]
# ## <font color='violet'>__Context__</font>

# %% [markdown]
# Access to safe-drinking water is essentil to health,a basic human right and a component of effective policy for health protection.This is important as a health and developement issue at a national,regional and local level.In some regions it has been shown that investiments in water supply and sanitation can yield a net economic benefit, since the reduction in adverse in adviser health effects and health care costs outweigh the costs of undertaking the interventions

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline 
import warnings
warnings.filterwarnings('ignore')

# %%
#importing data set
df=pd.read_csv('E:\Rajeesh\Linear Regression\water_potability.csv')

# %% [markdown]
# # Understanding data set

# %%
#shape of the data set
df.shape
# Out:
# (3276, 10)

# %%
#number of null values in each column
df.isnull().sum()
# Out:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %%
#List of columns in an data set
df.columns
# Out:
# Index(['ph', 'Hardness', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity',
#        'Organic_carbon', 'Trihalomethanes', 'Turbidity', 'Potability'],
#       dtype='object')

# %%
#Sample data
df.sample(7)
# Out:
#              ph    Hardness        Solids  Chloramines     Sulfate  \
# 2710   5.654119  171.751551  16431.204897     7.283454  387.904632
# 441    6.529304  210.004033  28970.087606     4.250151         NaN
# 2192   6.704432  148.842129  13329.032253     7.118465         NaN
# 897   10.200645  182.080601   8016.202938     5.567501  337.781580
# 102    8.526170  175.612836  11837.123360     7.483709  308.398516
# 1225   7.871961  219.622659  12760.437151     8.076613  360.086657
# 1913   7.280560  228.539543  29690.917158     7.871025  322.269661
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 2710    419.097306       11.814852        86.308236   3.466264           1
# 441     422.817556        7.091298        83.690156   3.361088           0
# 2192    403.420996       20.794371        70.346102   3.395332           0
# 897     291.600283       13.469924        50.567372   5.174720           0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %%
#To display unique value in a data set
df.nunique()
# Out:
# ph                 2785
# Hardness           3276
# Solids             3276
# Chloramines        3276
# Sulfate            2495
# Conductivity       3276
# Organic_carbon     3276
# Trihalomethanes    3114
# Turbidity          3276
# Potability            2
# dtype: int64

# %%
df.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2785.000000  3276.000000   3276.000000  3276.000000  2495.000000
# mean      7.080795   196.369496  22014.092526     7.122277   333.775777
# std       1.594320    32.879761   8768.570828     1.583085    41.416840
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.093092   176.850538  15666.690297     6.127421   307.699498
# 50%       7.036752   196.967627  20927.833607     7.130299   333.073546
# 75%       8.062066   216.667456  27332.762127     8.114887   359.950170
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3114.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.396293     3.966786     0.390110
# std       80.824064        3.308162        16.175008     0.780382     0.487849
# ...

# %%
#Replacing the null value with mode of each column
df['ph']=df['ph'].fillna(df['ph'].mode()[0])
df['Sulfate']=df['Sulfate'].fillna(df['Sulfate'].mode()[0])
df['Trihalomethanes']=df['Trihalomethanes'].fillna(df['Trihalomethanes'].mode()[0])

# %%
#checking for null values
df.isnull().sum()
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# dtype: int64

# %% [markdown]
# # Data Vizualization

# %%
#Bar plot on Potability
df.Potability.value_counts()
# Out:
# 0    1998
# 1    1278
# Name: Potability, dtype: int64

# %%
df.Potability.value_counts().plot(kind='bar',color=['pink','violet'])
plt.show()

# %%
df.hist(figsize=(14,14))
plt.show()

# %%
#scatter plot on Potability and ph
sns.scatterplot(df['ph'],df['Potability'])
# Out:
# <AxesSubplot:xlabel='ph', ylabel='Potability'>

# %%
#creating a correlated heatmap
sns.heatmap(df.corr(),annot=True,cmap='terrain',linewidth=0.1)
fig=plt.gcf()
fig.set_size_inches(8,6)
plt.show()

# %%
#Feature and Target value

# %%
X=df.drop(['Potability'],axis='columns')
y=df['Potability']

# %%
X
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0     0.000000  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246  129.000000
# 2     8.099124  224.236259  19909.541732     9.275884  129.000000
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362  129.000000
# 3273  9.419510  175.762646  33155.578218     7.350233  129.000000
# 3274  5.126763  230.603758  11983.869376     6.303357  129.000000
# 3275  7.874671  195.102299  17404.177061     7.509306  129.000000
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity
# 0       564.308654       10.379783        86.990970   2.963135
# ...

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 3271    1
# 3272    1
# 3273    1
# 3274    1
# 3275    1
# Name: Potability, Length: 3276, dtype: int64

# %%
#find correlation between columns and remove the most correlated columns
def correlation(X,threshold):
    corr_col=set()
    correlation_matrix=X.corr()
    for i in range(len(correlation_matrix.columns)):
        for j in range(i):
            if correlation_matrix.iloc[i,j]>threshold:
                colname=correlation_matrix.columns[i]
                corr_col.add(colname)
    return corr_col

# %%
#calling function
#No correlation found between columns
correlation(X,0.8)
# Out:
# set()

# %%
#Applying Scaling Tecnic
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(X)
X1=scaler.transform(X)

# %%
#X after applying Standard Scaling
X1
# Out:
# array([[-2.05883481,  0.25919471, -0.13947087, ..., -1.18065057,
#          1.12233819, -1.28629758],
#        [-0.78784149, -2.03641367, -0.38598665, ...,  0.27059724,
#         -0.32106895,  0.68421789],
#        [ 0.7112704 ,  0.84766483, -0.24004734, ...,  0.78111686,
#          0.15396513, -1.16736546],
#        ...,
#        [ 1.16287583, -0.62682923,  1.27080989, ..., -0.98132923,
#          0.31521132, -0.85600678],
#        [-0.30535229,  1.0413545 , -1.14405809, ..., -0.94206382,
#          0.67499636,  0.95079738],
#        [ 0.63450186, -0.03854623, -0.52581194, ...,  0.56094007,
#          0.73196803, -2.12445866]])

# %%
#Train Test Split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X1,y,test_size=0.2,random_state=100)

# %%
X_train.shape
# Out:
# (2620, 9)

# %%
y_train.shape
# Out:
# (2620,)

# %%
y_test.shape
# Out:
# (656,)

# %%
X_test.shape
# Out:
# (656, 9)

# %%
# !pip install xgboost

# %%
def ai_pipeline(X=X_train,y=y_train,xx=X_test,yy=y_test):
    #Linear Algorithms & Classification Algorithm
    from sklearn.linear_model import LinearRegression,LogisticRegression
    from sklearn.tree import DecisionTreeRegressor,DecisionTreeClassifier
    from sklearn.ensemble import RandomForestRegressor,RandomForestClassifier,GradientBoostingClassifier
    from xgboost import XGBRegressor,XGBClassifier
    from sklearn.neighbors import KNeighborsClassifier
    #Graph
    import matplotlib.pyplot as plt
    # %matplotlib inline
    
    import pandas as pd
    
    algorithm_list={LinearRegression():'linear Regression',DecisionTreeRegressor():'DecisionTree Regressor',
        RandomForestRegressor():'RandomForest Regressor',LogisticRegression():'Logistic Regression',
        XGBRegressor():'XGBoost Regressor',DecisionTreeClassifier():'Decisiontree Classifier',
        RandomForestClassifier():'RandomForest Classifier',KNeighborsClassifier():'KNeighbors Classifier',
        XGBClassifier():'XGBoost Classifier',GradientBoostingClassifier():'GradientBoosting Classifier'
       }
    Test_result=[]
    Train_result=[]
    short_name=[]
    for i,j in algorithm_list.items():
        #creating object for algorithm list
        model=i
        #fitting the train data
        i.fit(X,y)
        #getting the score
        train_score=i.score(X,y)
        test_score=i.score(xx,yy)
        #displaying the result
        print(f'{j}; Score; Train : {round(i.score(X,y),2)} Test : {round(i.score(xx,yy),2)}')
        Test_result.append(test_score)
        Train_result.append(train_score)
        short_name.append(j[:5])
        import numpy as np

        plt.rcParams["figure.figsize"] = [7.50, 3.50]
        plt.rcParams["figure.autolayout"] = True

        test_line = np.array(Test_result)
        train_line = np.array(Train_result)

        ax1 = plt.subplot()
        l1, = ax1.plot(test_line, color='green',marker='o')
        ax2 = ax1.twinx()
        l2, = ax2.plot(train_line, color='red',marker='o')

        plt.legend([l1, l2], ["test_line", "train_line"])
        plt.title(j.capitalize(),fontsize=12)
        plt.grid(True)
        plt.show()

# %%
ai_pipeline(X=X_train,xx=X_test,y=y_train,yy=y_test)
# Out:
# linear Regression; Score; Train : 0.0 Test : 0.0
# DecisionTree Regressor; Score; Train : 1.0 Test : -0.7
# RandomForest Regressor; Score; Train : 0.87 Test : 0.11
# Logistic Regression; Score; Train : 0.61 Test : 0.61
# XGBoost Regressor; Score; Train : 0.92 Test : -0.04
# Decisiontree Classifier; Score; Train : 1.0 Test : 0.6
# RandomForest Classifier; Score; Train : 1.0 Test : 0.68
# KNeighbors Classifier; Score; Train : 0.75 Test : 0.56
# XGBoost Classifier; Score; Train : 1.0 Test : 0.65
# GradientBoosting Classifier; Score; Train : 0.73 Test : 0.65

# %% [markdown]
# # Summary

# %% [markdown]
# After analysing the data set of water potablity <font color='green'>__Random forest Classification__ </font>provide an result of <font color='red'>__68 %__</font> of test accuracy as compare to other machine learning algorithm
